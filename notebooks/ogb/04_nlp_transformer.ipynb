# %% [markdown]
# # Natural Language Processing With Transformers
# TODO: Notebook Overview
#
# ## Transformer Anatomy
# TODO: Briefly Describe the anatomy of a transformer

# %% [markdown]
# ## Project Setup

# %% [markdown]
# ## Mapping & Sanity Check
#
# Focus: map the text to the node, and make sure the mapping is legit.
#
# Progress targets
#
# Build a deterministic join from node_index → paper_id, then to your title/abstract table.
#
# Canonicalize keys: strip version suffixes like v\d+, trim, lowercase, normalize Unicode.
#
# Create a cached table arxiv_text.parquet with at least:
# node_index, paper_id, year, text (title + abstract), label, split.
#
# Map the label and read a few entries to see whether the label makes sense.

# %% [markdown]
# ## Encoding Exploration
# Focus: explore different text encoding methods with a linear probe and compare performance.
#
# Progress targets:
#
# TF-IDF
#
# Encode abstracts with TF-IDF (with/without n-grams (n = 2, 3, 5)) and use logistic regression as the prediction head.
#
# Optionally apply stopwords, lemmatization, etc.
#
# Record results and explain what drives differences.
#
# Word2Vec
#
# Use a pretrained Word2Vec model (e.g., word2vec-google-news-300) to encode abstracts and train a logistic regression head.
#
# Record results.
#
# (Optional) Train your own Word2Vec model on the training set and compare.
#
# Modern Embedding Methods
#
# Try modern embedding models (e.g., EmbeddingGemma, GPT-4) to encode and run the same experiment.
#
# By end of Week 8, you should have:
#
# Completed all experiments and presented the performance under three different settings.

# %% [markdown]
# ## Benchmarks: Encoder-Only Transformer From Scratch
# Objective: Train a small encoder-only transformer using the dataset’s text (e.g., titles + abstracts).
#
# Describe briefly:
#
# Model size (#layers, heads, hidden dim)
#
# Training configuration (optimizer, learning rate, etc.)
#
# What features or embeddings are being fed to it.

# %% [markdown]
# ### Results
# Results:
#
# Validation Accuracy, Macro-F1, Learning Curves
#
# Observations about overfitting or training stability.

# %% [markdown]
# ## Benchmarks: Bidirectional Encoder Representations From Transformers (BERT)
# Objective: Use a pretrained BERT-base model (frozen or fine-tuned).
#
# Experiment Notes:
#
# Frozen encoder with linear head
#
# Fine-tuned (if VRAM allows)
#
# Learning rate, epochs, and dataset preprocessing steps

# %% [markdown]
# ### Results
#
# Results:
#
# Table with Accuracy, F1-score
#
# Notes on generalization gap
#
# Observed attention patterns (optional qualitative notes)

# %% [markdown]
# ## Benchmarks: Decoding-enhanced BERT with Disentangled Attention
# Objective: Evaluate DeBERTa under the same conditions for direct comparison.
#
# Briefly note:
#
# Key differences from BERT (disentangled attention, relative position encoding)
#
# Same metrics and evaluation pipeline.

# %% [markdown]
# ### Results
# Results:
#
# Metric table (Accuracy, F1)
#
# Optional: efficiency or inference speed comparison.

# %% [markdown]
# ## Comparative Analysis
